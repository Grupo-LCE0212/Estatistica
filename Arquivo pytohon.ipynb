# %% [markdown]
# <a href="https://colab.research.google.com/github/Grupo-LCE0212/Estatistica/blob/main/Arquivo%20pytohon.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Meu primeiro código em Python
#
# Faça alguma descrição...
#
# ## Nada é bom
#
# Algum texto legal
#
# a²+b²=c²

# %%
import pandas as pd

file_path = 'dados.xlsx'

try:
    df = pd.read_excel(file_path)
    print("Dados importados com sucesso!")
    print("As primeiras 5 linhas do DataFrame são:")
    display(df.head(23))
except FileNotFoundError:
    print(f"Erro: O arquivo '{file_path}' não foi encontrado. Verifique o caminho do arquivo.")
except Exception as e:
    print(f"Ocorreu um erro ao ler o arquivo XLSX: {e}")
# Out:
# Dados importados com sucesso!
# As primeiras 5 linhas do DataFrame são:
#       Carimbo de data/hora              Nome ou apelido  \
# 0  2026-08-03 19:11:11.422                      Gustavo
# 1  2026-08-03 19:11:16.191                        laura
# 2  2026-08-03 19:11:31.786                      Nayara
# 3  2026-08-03 19:11:34.070                        Lais
# 4  2026-08-03 19:12:04.182                          NaN
# 5  2026-08-03 19:12:12.199                        Karin
# 6  2026-08-03 19:12:12.228  Luciana Gouveia dos Santos
# 7  2026-08-03 19:12:15.808                          NaN
# 8  2026-08-03 19:12:23.345                      Melissa
# 9  2026-08-03 19:12:27.115                     Carolina
# 10 2026-08-03 19:12:33.366                      Mariana
# 11 2026-08-03 19:12:35.888  Cristina Pan Motta Oliverio
# 12 2026-08-03 19:12:37.942                     Luciana
# 13 2026-08-03 19:12:43.030                     Beatriz
# 14 2026-08-03 19:12:46.884       João Pedro Paschoalini
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Nome da coluna que o usuário pediu para plotar
column_name = "Qual dessas frutas você prefere para suco natural?"

# Verificar se a coluna existe no DataFrame
if column_name in df.columns:
    # Contar a frequência de cada fruta
    fruit_counts = df[column_name].value_counts()

    # Criar o gráfico de barras
    plt.figure(figsize=(10, 6))
    sns.barplot(x=fruit_counts.index, y=fruit_counts.values, palette='viridis')
    plt.title(f'Preferência de Frutas para Suco Natural ({column_name})')
    plt.xlabel('Frutas')
    plt.ylabel('Número de Respostas')
    plt.xticks(rotation=90, ha='right') # Rotacionar rótulos para melhor leitura
    plt.tight_layout()
    plt.show()
else:
    print(f"Erro: A coluna '{column_name}' não foi encontrada no DataFrame. Verifique o nome da coluna.")
# Out:
# /tmp/ipykernel_3853/2312774912.py:14: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=fruit_counts.index, y=fruit_counts.values, palette='viridis')
